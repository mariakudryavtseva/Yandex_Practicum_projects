# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Приведение-столбцов-таблиц-к-единому-стилю" data-toc-modified-id="Приведение-столбцов-таблиц-к-единому-стилю-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Приведение столбцов таблиц к единому стилю</a></span></li><li><span><a href="#Приведение-типов-данных" data-toc-modified-id="Приведение-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Приведение типов данных</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Поиск-выбивающихся-значений" data-toc-modified-id="Поиск-выбивающихся-значений-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Поиск выбивающихся значений</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Минимальная-и-максимальная-дата-привлечения" data-toc-modified-id="Минимальная-и-максимальная-дата-привлечения-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Минимальная и максимальная дата привлечения</a></span></li><li><span><a href="#Анализ-пользователей" data-toc-modified-id="Анализ-пользователей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ пользователей</a></span></li></ul></li><li><span><a href="#Метрики-и-отчеты" data-toc-modified-id="Метрики-и-отчеты-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Метрики и отчеты</a></span><ul class="toc-item"><li><span><a href="#Продукт" data-toc-modified-id="Продукт-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Продукт</a></span><ul class="toc-item"><li><span><a href="#DAU,-WAU,-MAU" data-toc-modified-id="DAU,-WAU,-MAU-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>DAU, WAU, MAU</a></span></li><li><span><a href="#Количество-пользовательских-сессий" data-toc-modified-id="Количество-пользовательских-сессий-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Количество пользовательских сессий</a></span></li><li><span><a href="#Длительность-пользовательской-сессии" data-toc-modified-id="Длительность-пользовательской-сессии-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Длительность пользовательской сессии</a></span></li></ul></li><li><span><a href="#Продажи" data-toc-modified-id="Продажи-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Продажи</a></span><ul class="toc-item"><li><span><a href="#Среднее-время-до-покупки" data-toc-modified-id="Среднее-время-до-покупки-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Среднее время до покупки</a></span></li><li><span><a href="#Количество-покупок" data-toc-modified-id="Количество-покупок-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Количество покупок</a></span></li><li><span><a href="#Средний-чек" data-toc-modified-id="Средний-чек-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Средний чек</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Расходы на маркетинг</a></span></li><li><span><a href="#Стоимость-привлечения-пользователя" data-toc-modified-id="Стоимость-привлечения-пользователя-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Стоимость привлечения пользователя</a></span></li></ul></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа" data-toc-modified-id="Функции-для-расчета-и-анализа-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Функции для расчета и анализа</a></span><ul class="toc-item"><li><span><a href="#Функция-для-расчёта-удержания-пользователей" data-toc-modified-id="Функция-для-расчёта-удержания-пользователей-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Функция для расчёта удержания пользователей</a></span></li><li><span><a href="#Функция-для-расчета-конверсии-пользователей" data-toc-modified-id="Функция-для-расчета-конверсии-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Функция для расчета конверсии пользователей</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-устройствам" data-toc-modified-id="Конверсия-и-удержание-по-устройствам-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Конверсия и удержание по устройствам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-рекламным-каналам" data-toc-modified-id="Конверсия-и-удержание-по-рекламным-каналам-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Конверсия и удержание по рекламным каналам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-странам" data-toc-modified-id="Конверсия-и-удержание-по-странам-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Конверсия и удержание по странам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Аналитическое исследование приложения Procrastinate Pro+

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Импортируем необходимые для работы библиотеки.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# загружаем данные из файлов
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info.csv'), # журнал сессий
    pd.read_csv('/datasets/orders_info.csv'), # заказы
    pd.read_csv('/datasets/costs_info.csv'), # траты на рекламу
)

# %%
# получение 5 случайных строк полученных таблиц
# и информации о них
for table in [visits, orders, costs]:
    display(table.sample(5))
    table.info()
# Out:
#              User Id         Region   Device             Channel  \
# 287431  979397125179             UK       PC             organic
# 238283  702154406382             UK  Android      WahooNetBanner
# 298185  101824472672             UK      Mac  OppleCreativeMedia
# 68174   864885507060  United States   iPhone             organic
# 298811  746865031720        Germany       PC             organic
#
#            Session Start       Session End
# 287431  27.09.2019 04:41  27.09.2019 05:05
# 238283  02.07.2019 21:59  02.07.2019 22:03
# 298185  11.10.2019 10:02  11.10.2019 10:07
# 68174   07.07.2019 12:16  07.07.2019 12:19
# 298811  12.10.2019 06:18  12.10.2019 06:30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# ...

# %% [markdown]
# Согласно документации к данным таблица `visits` содержит:
# * `User Id` — уникальный идентификатор пользователя;
# * `Device` — категория устройства пользователя;
# * `Session start` — дата и время начала сессии;
# * `Session End` — дата и время окончания сессии;
# * `Channel` — идентификатор рекламного источника, из которого пришел пользователь;
# * `Region` - страна пользователя.
#
# Таблица `orders`:
# * `User Id` — уникальный id пользователя, который сделал заказ;
# * `Event Dt` — дата и время покупки;
# * `Revenue` — выручка.
#
# Таблица `costs`:
# * `Channel` — идентификатор рекламного источника;
# * `Dt` — дата;
# * `Costs` — затраты на этот рекламный источник в этот день.

# %% [markdown]
# Пропущенных значений в таблицах нет, но замечаем нарушение стиля в названиях колонок. Кроме того, столбцы `Session start`, `Session End`, `Event Dt`, `Dt`, содержащие даты, имеют формат данных `object`, что не позволит работать со значениями столбцов как с датами.

# %% [markdown]
# ***Вывод***
#
# В процессе обзора полученных данных о визитах пользователей, заказах и расходах на рекламу было обнаружено, что в таблицах есть нарушения стиля в названиях колонок и проблемы с форматом данных в столбцах, содержащих даты. Таким образом, необходимо устранить все недочеты в данных для их более эффективного использования в нашем исследовании.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Приведение столбцов таблиц к единому стилю

# %% [markdown]
# Исправим стили в заголовках столбцов таблиц `visits`, `orders` и `costs`.

# %%
# создание новых названий для стобцов таблиц
visits_list = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']
orders_list = ['user_id', 'event_dt', 'revenue']
costs_list = ['dt', 'channel', 'costs']

# переименование столбцов в таблицах
visits.columns = visits_list
orders.columns = orders_list
costs.columns = costs_list

# проверка переименования стобцов таблиц
for table in [visits, orders, costs]:
    display(table.head(5))
# Out:
#         user_id         region   device  channel     session_start  \
# 0  981449118918  United States   iPhone  organic  01.05.2019 02:36
# 1  278965908054  United States   iPhone  organic  01.05.2019 04:46
# 2  590706206550  United States      Mac  organic  01.05.2019 14:09
# 3  326433527971  United States  Android   TipTop  01.05.2019 00:29
# 4  349773784594  United States      Mac  organic  01.05.2019 03:33
#
#         session_end
# 0  01.05.2019 02:45
# 1  01.05.2019 04:47
# 2  01.05.2019 15:32
# 3  01.05.2019 00:54
# 4  01.05.2019 03:57
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# ...

# %% [markdown]
# ### Приведение типов данных

# %% [markdown]
# Приведем столбцы, содержащие данные о датах, к соответствующему типу.

# %%
# задаем формат данных даты и приводим стобцы
# к нужному формату
time_format = '%d.%m.%Y %H:%M'
visits['session_start'] = pd.to_datetime(visits['session_start'], format = time_format)
visits['session_end'] = pd.to_datetime(visits['session_end'], format = time_format)
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# получение информации о таблицах
for table in [visits, orders, costs]:
    table.info()
    print('***')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# user_id          309901 non-null int64
# region           309901 non-null object
# device           309901 non-null object
# channel          309901 non-null object
# session_start    309901 non-null datetime64[ns]
# session_end      309901 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# ***
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# user_id     40212 non-null int64
# event_dt    40212 non-null datetime64[ns]
# revenue     40212 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ***
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# channel    1800 non-null object
# costs      1800 non-null float64
# ...

# %% [markdown]
# ### Поиск дубликатов

# %% [markdown]
# Проверим данные в таблицах на явные дубликаты.

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Поиск выбивающихся значений

# %% [markdown]
# Проверим числовые данные в таблицах `orders` и `costs` на наличие аномалий и выбивающихся значений.

# %%
# статистика для данных числовых столбцов
orders.describe()
# Out:
#             user_id       revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %%
# выбираем записи со стоимостью заказа 49.99 у.е.
orders_max = orders[orders['revenue'] == 49.99]
orders_max.head(10)
# Out:
#             user_id            event_dt  revenue
# 207    696998937855 2019-05-07 01:32:00    49.99
# 244    423175451214 2019-05-08 15:58:19    49.99
# 667    698825366282 2019-05-14 20:39:52    49.99
# 862    243524410124 2019-05-17 23:29:54    49.99
# 1021   752744133703 2019-05-19 11:38:40    49.99
# ...             ...                 ...      ...
# 39058   75914663007 2019-10-20 17:33:37    49.99
# 39067  610997074195 2019-10-20 02:53:44    49.99
# 39324  470751600769 2019-10-23 07:20:55    49.99
# 39481  387107442792 2019-10-24 22:42:12    49.99
# 39550  968421663220 2019-10-25 05:00:33    49.99
#
# [212 rows x 3 columns]

# %% [markdown]
# По полученным данным о таблице `orders` мы можем сказать, что основная стоимость продукта составляет 4.99 у.е., но некоторые пользователи оплатили в 10 раз больше - 49.99 у.е. Количество таких пользователей составляет всего 0.5% от общего числа покупок, но искажает среднее и медианное значение `revenue`. Поскольку нам неизвестно ошибочные это записи или приложение действительно имеет опции с увеличенной стоимостью, оставим такие их без изменений на данный момент.

# %%
# статистика для данных числовых столбцов
costs.describe()
# Out:
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000

# %%
# построение "ящика с усами" для значений стоимости рекламы
costs.boxplot('costs', figsize=(8,6))
plt.show()

# %%
# выбираем записи со стоимостью рекламы более 50 у.е.
costs_max = costs[costs['costs'] >= 50]
costs_max
# Out:
#               dt         channel   costs
# 0     2019-05-01        FaceBoom  113.30
# 1     2019-05-02        FaceBoom   78.10
# 2     2019-05-03        FaceBoom   85.80
# 3     2019-05-04        FaceBoom  136.40
# 4     2019-05-05        FaceBoom  122.10
# ...          ...             ...     ...
# 903   2019-05-04      AdNonSense   51.45
# 918   2019-05-19      AdNonSense   53.55
# 926   2019-05-27      AdNonSense   56.70
# 1590  2019-09-28  WahooNetBanner   52.20
# 1591  2019-09-29  WahooNetBanner   53.40
#
# [363 rows x 3 columns]

# %% [markdown]
# Проанализировав затраты на рекламу, мы видим, что 80% дней, в которые происходили рекламные кампании, компания тратила менее 50 у.е. на определенный рекламный ресурс. Но в некоторые дни траты на рекламу превышали этот порог в несколько раз и доходили до 630 у.е.

# %% [markdown]
# ***Вывод***
#
# Мы произвели предобработку данных в таблицах `visits`, `orders` и `costs`. Все столбцы таблиц были приведены к единому стилю, а столбцы, содержащие данные о датах, к соответствующему типу. Явные дубликаты в таблицах не были найдены. Также мы проанализировали числовые данные в таблицах `orders` и `costs` и обнаружили, что небольшая часть покупок была совершена по цене в 10 раз превышающей основную цену продукта и что в некоторые дни компания вкладывала в рекламные кампании в несколько раз больше средств, чем обычно.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей

# %% [markdown]
# Определим профили пользователей по полученным наборам данным. Для создания пользовательских профилей с датой первого посещения, источником перехода на сайт, использованным устройством и регионом пользователя используем функцию `get_profiles()`.

# %%
def get_profiles(visits, orders):
    
    # сортируем сессии по ID пользователя и дате посещения
    # группируем по ID и находим первые значения session_start,
    # channel, device, region
    # столбец с временем первого посещения - first_ts
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    profiles['dt'] = profiles['first_ts'].dt.date
    
    # проверяем, есть ли ID пользователей из profiles в orders
    profiles['payer'] =  profiles['user_id'].isin(orders['user_id'].unique())

    return profiles

# строим профили по двум наборам данных
profiles = get_profiles(visits, orders)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:00      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:00      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:00       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:00    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:00       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:00        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:00       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:00        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:00  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:00       organic  iPhone  United States
#
#                 dt  payer
# ...

# %% [markdown]
# ### Минимальная и максимальная дата привлечения

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей.

# %%
# доступный интервал привлечения пользователей
min_analysis_date = profiles['dt'].min()
max_analysis_date = profiles['dt'].max()
print('Минимальная дата привлечения:', min_analysis_date.strftime("%x"))
print('Максимальная дата привлечения:', max_analysis_date.strftime("%x"))
# Out:
# Минимальная дата привлечения: 05/01/19
# Максимальная дата привлечения: 10/27/19

# %% [markdown]
# ### Анализ пользователей

# %% [markdown]
# Выясним из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
# группируем по странам, находим количество пользователей
# и долю платящих пользователей
display(
    profiles.groupby('region')
    .agg({'user_id': 'nunique','payer': lambda x: '{:.2%}'.format(x.mean())})
    .sort_values(by=['user_id','payer'], ascending=False)
)
# Out:
#                user_id  payer
# region
# United States   100002  6.90%
# UK               17575  3.98%
# France           17450  3.80%
# Germany          14981  4.11%

# %% [markdown]
# Также узнаем какими устройствами пользуются посетители и с каких устройств чаще всего заходят пользователи, совершившие покупку.

# %%
# группируем по устройствам, находим количество пользователей
# и долю платящих пользователей
display(
    profiles.groupby('device')
    .agg({'user_id': 'nunique','payer': lambda x: '{:.2%}'.format(x.mean())})
    .sort_values(by=['user_id','payer'], ascending=False)
)
# Out:
#          user_id  payer
# device
# iPhone     54479  6.21%
# Android    35032  5.85%
# PC         30455  5.05%
# Mac        30042  6.36%

# %% [markdown]
# Оценим по каким рекламным каналам шло привлечение пользователей и какие из них приносят больше всего платящих пользователей.

# %%
# группируем по каналам привлечения, находим количество пользователей
# и долю платящих пользователей
display(
    profiles.groupby('channel')
    .agg({'user_id': 'nunique','payer': lambda x: '{:.2%}'.format(x.mean())})
    .sort_values(by=['user_id','payer'], ascending=False)
)
# Out:
#                     user_id   payer
# channel
# organic               56439   2.06%
# FaceBoom              29144  12.20%
# TipTop                19561   9.60%
# OppleCreativeMedia     8605   2.71%
# WahooNetBanner         8553   5.30%
# LeapBob                8553   3.06%
# RocketSuperAds         4448   7.91%
# MediaTornado           4364   3.57%
# YRabbit                4312   3.83%
# AdNonSense             3880  11.34%
# lambdaMediaAds         2149  10.47%

# %% [markdown]
# ***Вывод***

# %% [markdown]
# В рамках исследовательского анализа мы построили профили пользователей и выяснили, что минимальная дата их привлечения - 1 мая 2019 года, а максимальная - 27 октября 2019 года. Также мы определили, что больше всего пользователей приложения из `United States` и доля платящих посетителей в `United States` выше всего - 6.90%. Чаще всего посетители используют для входа в приложение `IPhone`, но доля платящих выше у той группы пользователей, кто использовал `Mac` - 6.36%. Кроме того, наибольшее число посетителей органические, то есть нашли приложение не используя рекламные каналы, но доля платящих пользователей в этой группе ниже всего - 2.06%. Наибольшая доля платящих пользователей была привлечена рекламной кампанией из `FaceBoom` - 12.20%.

# %% [markdown]
# ## Метрики и отчеты

# %% [markdown]
# Посчитаем метрики по трём направлениям: продукт, продажи и маркетинг.

# %% [markdown]
# ### Продукт

# %% [markdown]
# #### DAU, WAU, MAU

# %% [markdown]
# Выясним, сколько людей пользуются приложением в день, неделю и месяц. Рассчитаем `DAU (daily active users)`, `WAU (weekly active users)` и `MAU (monthly active users)`.

# %%
# выделяем месяц, неделю и дату из времени начала сессии
visits['mau_month'] = visits['session_start'].astype('datetime64[M]')
visits['wau_week'] = visits['session_start'].astype('datetime64[W]')
visits['dau_day'] = visits['session_start'].dt.date

# %%
visits.sample(5)
# Out:
#              user_id         region   device  channel       session_start  \
# 172864  644069062748  United States  Android   TipTop 2019-10-04 00:07:00
# 87733   558227141868  United States  Android  organic 2019-07-27 20:39:00
# 54460   952920119276  United States  Android  organic 2019-06-26 12:46:00
# 232650  826851107492             UK  Android  organic 2019-06-22 06:44:00
# 4779     13088484117  United States      Mac  organic 2019-05-06 11:50:00
#
#                session_end  mau_month   wau_week     dau_day
# 172864 2019-10-04 01:00:00 2019-10-01 2019-10-03  2019-10-04
# 87733  2019-07-27 20:53:00 2019-07-01 2019-07-25  2019-07-27
# 54460  2019-06-26 14:29:00 2019-06-01 2019-06-20  2019-06-26
# 232650 2019-06-22 07:43:00 2019-06-01 2019-06-20  2019-06-22
# 4779   2019-05-06 12:11:00 2019-05-01 2019-05-02  2019-05-06

# %%
# расчет DAU, WAU, MAU
# группируем данные по дате, неделе, месяцу,
# считаем количество уникальных пользователей, находим среднее

dau_total = (
    visits.groupby('dau_day').agg({'user_id': 'nunique'}).mean()
)
wau_total = (
    visits.groupby('wau_week').agg({'user_id': 'nunique'}).mean()
)
mau_total = (
    visits.groupby('mau_month').agg({'user_id': 'nunique'}).mean()
)

# вывод результата
print('Среднее количество пользователей в день:', int(dau_total))
print('Среднее количество пользователей в неделю:', int(wau_total))
print('Среднее количество пользователей в месяц:', int(mau_total))
# Out:
# Среднее количество пользователей в день: 1684
# Среднее количество пользователей в неделю: 7942
# Среднее количество пользователей в месяц: 28989

# %% [markdown]
# Отобразим изменения этих метрик во времени на графиках.

# %%
# построение графика для DAU
visits.groupby('dau_day').agg({'user_id': 'nunique'}).plot(grid=True, figsize=(15,5))
plt.axhline(y=int(dau_total), color='r', linestyle = 'dashed', label = 'среднее значение')
plt.xlabel('Дни')
plt.ylabel('Количество уникальных пользователей')
plt.title('График изменения DAU во времени')
plt.show()

# %% [markdown]
# По графику изменения DAU мы видим, что активность пользователей меняется  предположительно в зависимости от рабочих/нерабочих дней.

# %%
# построение графика для WAU
(visits
 .groupby(['wau_week'])
 .agg({'user_id': 'nunique', 'dau_day' : 'nunique'})
 .query('dau_day == 7')
)['user_id'].plot(grid=True, figsize=(15,5))

plt.xlabel('Недели')
plt.ylabel('Количество уникальных пользователей')
plt.title('График изменения WAU во времени')
plt.show()

# %% [markdown]
# Здесь наблюдаем тенденцию к падению числа пользователей в первую недели большинства месяцев и его рост в середине месяца (исключая июль).

# %%
# построение графика для MAU
visits.groupby('mau_month').agg({'user_id': 'nunique'}).plot(grid=True, figsize=(15,5))
plt.xlabel('Месяцы')
plt.ylabel('Количество уникальных пользователей')
plt.title('График изменения MAU во времени')
plt.show()

# %% [markdown]
# Количество пользователей резко стало увеличиваться с июля и достигло максимума в сентябре. Далее мы наблюдаем снижение уникальных посетителей в приложении.
# Явно выраженной сезонности в данных не наблюдается. Пики в посещаемости могут быть вызваны внешними факторами, например, активными рекламными кампаниями.

# %% [markdown]
# #### Количество пользовательских сессий

# %% [markdown]
# Изучим число пользовательских сессий.

# %%
# расчет количества сессий в день
sessions_per_day = visits.groupby('dau_day').agg(
    {'user_id': 'count'}
)

# среднее количество сессий в день
visits_mean = sessions_per_day['user_id'].mean()
print('Среднее количество сессий в день:', int(visits_mean))

# построение гистрограммы распределения общего числа сессий в день
ax = sessions_per_day['user_id'].hist(bins=20)
# параметры для осей X, Y и title
ax.set(title='Гистограмма количества пользовательских сессий', xlabel='Количество сессий', ylabel='Количество дней')
ax;
# Out:
# Среднее количество сессий в день: 1684

# %% [markdown]
# Анализируя гистограмму мы можем сказать, что большая часть дней рассматриваемого периода имела от 1500 до 2000 пользовательских сессий. А среднее количество сессий в день близко по значению к `DAU`.

# %% [markdown]
# #### Длительность пользовательской сессии

# %%
# расчет длительности сессии
visits['session_duration_sec'] = (
    visits['session_end'] - visits['session_start']
).dt.total_seconds()

# вывод результата как медиана от значений длительности
print('Медианная длительность пользовательской сессии:', visits['session_duration_sec'].median()) 
visits.head(5)
# Out:
# Медианная длительность пользовательской сессии: 1260.0
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:00
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:00
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:00
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:00
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:00
#
#           session_end  mau_month   wau_week     dau_day  session_duration_sec
# 0 2019-05-01 02:45:00 2019-05-01 2019-04-25  2019-05-01                 540.0
# 1 2019-05-01 04:47:00 2019-05-01 2019-04-25  2019-05-01                  60.0
# 2 2019-05-01 15:32:00 2019-05-01 2019-04-25  2019-05-01                4980.0
# 3 2019-05-01 00:54:00 2019-05-01 2019-04-25  2019-05-01                1500.0
# 4 2019-05-01 03:57:00 2019-05-01 2019-04-25  2019-05-01                1440.0

# %%
# построение гистограммы распределения длительности сессий
ax = visits['session_duration_sec'].hist(bins=100)
ax.set(title='Гистограмма распределения длительности сессий', xlabel='Длительность сессии', ylabel='Количество сессий (сек)')
ax;

# %% [markdown]
# Гистограмма показывает, что большинство сессий менее 3000 секунд, но есть слишком продолжительные сессии (более 20000 сек.). Поэтому выше мы считали медианное значение продолжительности сессии (исключить влияние таких длинных сессий на результат).

# %%
# построение таблицы с параметрами распределения
visits['session_duration_sec'].describe()
# Out:
# count    309901.000000
# mean       1800.084801
# std        1803.189827
# min           0.000000
# 25%         540.000000
# 50%        1260.000000
# 75%        2520.000000
# max       22260.000000
# Name: session_duration_sec, dtype: float64

# %% [markdown]
# Изучив таблицу с параметрами распределения, мы можем убедиться, что выбросы в значениях продолжительсти сессии существуют. Поэтому среднее значение продолжительности сессий сильно отличается от медианного. Мы видим что 75% сессий имеют продолжительность до 3000 сек., как мы наблюдали на гистограмме выше.

# %% [markdown]
# ***Вывод***
#
# Изучив метрики по направлению "Продукт" мы вычислили сколько людей пользуются приложением в день, неделю и месяц. Пользователи приходят в приложении не стабильно, наблюдаются пики их активности и резкие падения. Можно связать это с внешними факторами, созданием рекламной кампании или особенностями дня недели (выходной/отпуск). Также мы выяснили, что среднее количество сессий в день близко к DAU. Мы определили медианное значение длительности пользовательской сессии и оно намного ниже среднего значения в виду наличия в значениях очень продолжительных сессий (выбросов).

# %% [markdown]
# ### Продажи

# %% [markdown]
# #### Среднее время до покупки

# %% [markdown]
# Исследуем, сколько времени в среднем проходит с момента первого посещения до покупки.

# %%
# даты первых покупок
first_purchases = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

# добавление даты первой покупки в таблицу с профилями
profiles_event = profiles.merge(
        first_purchases, on='user_id', how='inner'
    )
profiles_event.head(5)
# Out:
#      user_id            first_ts     channel   device         region  \
# 0     599326 2019-05-07 20:58:00    FaceBoom      Mac  United States
# 1   46006712 2019-06-30 03:46:00  AdNonSense  Android         France
# 2  374052872 2019-08-08 15:42:00      TipTop      Mac  United States
# 3  414791703 2019-05-03 12:01:00      TipTop   iPhone  United States
# 4  785077127 2019-06-27 08:31:00      TipTop      Mac  United States
#
#            dt  payer            event_dt
# 0  2019-05-07   True 2019-05-07 20:59:09
# 1  2019-06-30   True 2019-06-30 03:46:52
# 2  2019-08-08   True 2019-08-16 07:44:47
# 3  2019-05-03   True 2019-05-04 18:06:41
# 4  2019-06-27   True 2019-06-30 18:35:15

# %%
# вычисление лайфтайма пользователей в секундах
profiles_event['lifetime'] = (
        profiles_event['event_dt'] - profiles_event['first_ts']
    ).dt.total_seconds() / 3600
profiles_event.head(5)
# Out:
#      user_id            first_ts     channel   device         region  \
# 0     599326 2019-05-07 20:58:00    FaceBoom      Mac  United States
# 1   46006712 2019-06-30 03:46:00  AdNonSense  Android         France
# 2  374052872 2019-08-08 15:42:00      TipTop      Mac  United States
# 3  414791703 2019-05-03 12:01:00      TipTop   iPhone  United States
# 4  785077127 2019-06-27 08:31:00      TipTop      Mac  United States
#
#            dt  payer            event_dt    lifetime
# 0  2019-05-07   True 2019-05-07 20:59:09    0.019167
# 1  2019-06-30   True 2019-06-30 03:46:52    0.014444
# 2  2019-08-08   True 2019-08-16 07:44:47  184.046389
# 3  2019-05-03   True 2019-05-04 18:06:41   30.094722
# 4  2019-06-27   True 2019-06-30 18:35:15   82.070833

# %%
# построение таблицы с параметрами распределения
profiles_event['lifetime'].describe()
# Out:
# count    8881.000000
# mean       45.197415
# std       144.872268
# min         0.000000
# 25%         0.011389
# 50%         0.019444
# 75%        35.481111
# max      3171.915278
# Name: lifetime, dtype: float64

# %% [markdown]
# Замечаем, что стандартное отклонение велико. А также мы видим, что максимальное значение времени покупки около часа. Среднее значение времени до покупки 45 секунд. Попробуем рассчитать так же медианное время с момента первого посещения до покупки.

# %%
# вывод результата как медиана от значений длительности
print('Медианное время до покупки:', profiles_event['lifetime'].median())
# Out:
# Медианное время до покупки: 0.019444444444444445

# %% [markdown]
# Таким образом, большинство пользователей совершает покупку в первую минуту, а медианное время меньше секунды.

# %% [markdown]
# #### Количество покупок

# %% [markdown]
# Рассчитаем среднее число покупок на одного покупателя за день, неделю и месяц.

# %%
# выделяем месяц, неделю и дату покупки
orders['buy_month'] = orders['event_dt'].astype('datetime64[M]')
orders['buy_week'] = orders['event_dt'].astype('datetime64[W]')
orders['buy_day'] = orders['event_dt'].dt.date

orders.head(5)
# Out:
#         user_id            event_dt  revenue  buy_month   buy_week     buy_day
# 0  188246423999 2019-05-01 23:09:52     4.99 2019-05-01 2019-04-25  2019-05-01
# 1  174361394180 2019-05-01 12:24:04     4.99 2019-05-01 2019-04-25  2019-05-01
# 2  529610067795 2019-05-01 11:34:04     4.99 2019-05-01 2019-04-25  2019-05-01
# 3  319939546352 2019-05-01 15:34:40     4.99 2019-05-01 2019-04-25  2019-05-01
# 4  366000285810 2019-05-01 13:59:51     4.99 2019-05-01 2019-04-25  2019-05-01

# %%
# считаем количество покупок и уникальных пользователей в день
orders_day = orders.groupby('buy_day').agg({'revenue': 'count', 'user_id': 'nunique'})
orders_day
# Out:
#             revenue  user_id
# buy_day
# 2019-05-01       25       25
# 2019-05-02       29       29
# 2019-05-03       44       44
# 2019-05-04       56       56
# 2019-05-05       58       58
# ...             ...      ...
# 2019-10-27      340      340
# 2019-10-28      287      287
# 2019-10-29      315      315
# 2019-10-30      238      238
# 2019-10-31      247      247
#
# [184 rows x 2 columns]

# %%
# считаем число покупок
orders_day['purchases'] = orders_day['revenue'] / orders_day['user_id']
orders_day.head(5)
# Out:
#             revenue  user_id  purchases
# buy_day
# 2019-05-01       25       25        1.0
# 2019-05-02       29       29        1.0
# 2019-05-03       44       44        1.0
# 2019-05-04       56       56        1.0
# 2019-05-05       58       58        1.0

# %%
# строим график покупок за день
orders_day['purchases'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# В среднем за весь период происходила одна покупка в день на уникального пользователя.

# %%
# считаем количество покупок и уникальных пользователей в неделю
orders_week = orders.groupby('buy_week').agg({'revenue': 'count', 'user_id': 'nunique'})
orders_week['purchases'] = orders_week['revenue'] / orders_week['user_id']
orders_week.head(5)
# Out:
#             revenue  user_id  purchases
# buy_week
# 2019-04-25       25       25   1.000000
# 2019-05-02      404      268   1.507463
# 2019-05-09      620      395   1.569620
# 2019-05-16      767      523   1.466539
# 2019-05-23      875      617   1.418152

# %%
# построение таблицы с параметрами распределения
orders_week['purchases'].describe()
# Out:
# count    28.000000
# mean      1.316172
# std       0.118059
# min       1.000000
# 25%       1.282209
# 50%       1.306324
# 75%       1.359679
# max       1.569620
# Name: purchases, dtype: float64

# %%
# строим график покупок за неделю
orders_week['purchases'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# В неделю происходило в среднем около 1.3 покупок на уникального пользователя.

# %%
# считаем количество покупок и уникальных пользователей в месяц
orders_month = orders.groupby('buy_month').agg({'revenue': 'count', 'user_id': 'nunique'})
orders_month['purchases'] = orders_month['revenue'] / orders_month['user_id']
orders_month.head(5)
# Out:
#             revenue  user_id  purchases
# buy_month
# 2019-05-01     2962     1226   2.415987
# 2019-06-01     4875     2130   2.288732
# 2019-07-01     6556     2801   2.340593
# 2019-08-01     7582     3476   2.181243
# 2019-09-01     8430     4124   2.044132

# %%
# построение таблицы с параметрами распределения
orders_month['purchases'].describe()
# Out:
# count    6.000000
# mean     2.228448
# std      0.144278
# min      2.044132
# 25%      2.120311
# 50%      2.234988
# 75%      2.327628
# max      2.415987
# Name: purchases, dtype: float64

# %%
# строим график покупок за месяц
orders_month['purchases'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# В месяц происходило в среднем около 2.2 покупок на уникального пользователя.

# %% [markdown]
# #### Средний чек

# %% [markdown]
# Рассчитаем средний чек пользователя за день, неделю и месяц.

# %%
# расчет среднего чека за день
bill_day = orders.groupby('buy_day').agg({'revenue': 'mean'})
bill_day['revenue'].describe()
# Out:
# count    184.000000
# mean       5.375884
# std        0.246025
# min        4.990000
# 25%        5.185476
# 50%        5.335974
# 75%        5.544885
# max        6.204286
# Name: revenue, dtype: float64

# %%
# строим график значений среднего чека за день
bill_day['revenue'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# Средний чек за день составляет 5,37 у.е.

# %%
# расчет среднего чека за неделю
bill_week = orders.groupby('buy_week').agg({'revenue': 'mean'})
bill_week['revenue'].describe()
# Out:
# count    28.000000
# mean      5.363435
# std       0.116345
# min       5.030000
# 25%       5.283347
# 50%       5.351724
# 75%       5.454608
# max       5.551881
# Name: revenue, dtype: float64

# %%
# строим график значений среднего чека за неделю
bill_week['revenue'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# Средний чек за неделю составляет 5,36 у.е.

# %%
# расчет среднего чека за месяц
bill_month = orders.groupby('buy_month').agg({'revenue': 'mean'})
bill_month['revenue'].describe()
# Out:
# count    6.000000
# mean     5.374169
# std      0.066684
# min      5.328565
# 25%      5.330270
# 50%      5.337955
# 75%      5.402071
# max      5.489390
# Name: revenue, dtype: float64

# %%
# строим график значений среднего чека за месяц
bill_month['revenue'].plot(grid=True, figsize=(15,5))

# %% [markdown]
# Средний чек за неделю составляет 5,37 у.е.

# %% [markdown]
# ***Вывод***
#
# Изучив метрики по направлению "Продажи" мы исследовали сколько времени в среднем проходит с момента первого посещения до покупки и выяснили, что большинству пользователей хватает минуты, чтобы совершить покупку в приложении. Также мы вычислили среднее число покупок на одного покупателя за день, неделю и месяц. В месяц происходит в среднем около 2.2 покупок на уникального пользователя, а в день всего одна. Пользователи редко совершают платежи в приложении и их пользовательская активность падает. Мы рассчитали средний чек за день, неделю и месяц. Он составляет для всех периодов около 5.3 у.е. Это значение незначительно колеблется, но остается в пределах между 5 и 6 у.е.

# %% [markdown]
# ### Маркетинг

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг и выясним, как траты распределены по рекламным источникам.

# %% [markdown]
# #### Расходы на маркетинг

# %%
# расчет общей суммы расходов на рекламу
total_cost = costs['costs'].sum()
print('Всего вложено на рекламные кампании: {:,.2f} у.е.'.format(total_cost))
# Out:
# Всего вложено на рекламные кампании: 105,497.30 у.е.

# %%
# расчет распределения трат по рекламным источникам
total_channel = costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)
total_channel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %%
# строим график трат по рекламным источникам за весь период
costs.pivot_table(
    index='dt', 
    columns='channel', 
    values='costs', 
    aggfunc='mean').plot(grid=True, figsize=(15, 7), legend=True)

# %% [markdown]
# В первую очередь мы видим, что с июня наблюдается увеличение вложений в рекламные кампании в канале TipTop. Наибольшее количество средств было потрачено на рекламные кампании в каналам FaceBoom и TipTop. На остальные каналы тратилось значительно меньшее и примерно одинаковое количество бюджетных средств.

# %% [markdown]
# #### Стоимость привлечения пользователя

# %% [markdown]
# Чтобы рассчитать и проанализировать `CAC (Customer Acquisition Cost)`, добавим данные о тратах на рекламу в пользовательские профили.

# %%
def profiles_acquisition(profiles, costs):
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()  # возвращаем dt и channel из индексов
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавим стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles  # возвращаем профили с CAC

# %%
# вызов функции расчета CAC
profiles = profiles_acquisition(profiles, costs)
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:00      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:00      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:00       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:00    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:00       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:00       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:00    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:00      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:00  MediaTornado   iPhone  United States
#
#            dt  payer  acquisition_cost
# 0  2019-05-07   True          1.088172
# 1  2019-07-09  False          1.107237
# 2  2019-10-01  False          0.000000
# ...

# %%
# расчет среднего CAC по рекламным источникам
channel_acquisition_cost = profiles.groupby('channel'
                                           ).agg({'acquisition_cost': 'mean'}
                                                ).sort_values(by='acquisition_cost',ascending=False)
channel_acquisition_cost
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
# исключим пользователей 'organic'
ad_acquisition_cost = profiles.query('acquisition_cost != 0')
ad_acquisition_cost.head(5)
# Out:
#     user_id            first_ts     channel   device         region  \
# 0    599326 2019-05-07 20:58:00    FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:00    FaceBoom   iPhone  United States
# 3  22593348 2019-08-22 21:35:00  AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:00     YRabbit   iPhone  United States
# 7  46006712 2019-06-30 03:46:00  AdNonSense  Android         France
#
#            dt  payer  acquisition_cost
# 0  2019-05-07   True          1.088172
# 1  2019-07-09  False          1.107237
# 3  2019-08-22  False          0.988235
# 4  2019-10-02  False          0.230769
# 7  2019-06-30   True          1.008000

# %%
# расчет среднего CAC для всего рекламного проекта
acquisition_cost_mean = ad_acquisition_cost['acquisition_cost'].mean()
print('Средний CAC на одного пользователя для всего проекта: {:,.2f} у.е.'.format(acquisition_cost_mean))
# Out:
# Средний CAC на одного пользователя для всего проекта: 1.13 у.е.

# %%
# строим график истории изменений CAC по каналам привлечения

profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 7))
plt.ylabel('CAC, у.е.')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Стоимость привлечения одного клиента росла значительно для рекламного канала TipTop. Цена привлечения клиентов в других каналах оставалась в среднем стабильной весь период.

# %% [markdown]
# ## Функции для расчета и анализа

# %% [markdown]
# Объявим функции для расчёта удержания, конверсии, LTV (Lifetime Value) и ROI (Return On Investment).

# %% [markdown]
# ### Функция для расчёта удержания пользователей

# %% [markdown]
# Функция позволит определить `retention rate`, который показывает, сколько пользователей относительно их изначального числа вернулись, то есть воспользовались нашим приложением, в последующие периоды.

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days
    
    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
     # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета конверсии пользователей

# %% [markdown]
# Функция вычисляет `conversion rate (CR)` - процент пользователей, совершивших покупку в нашем приложении.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %% [markdown]
# Используем функцию ниже, чтобы рассчитать `LTV (Lifetime Value)` - общую сумму денег, которую один клиент в среднем приносит компании со всех своих покупок - и `ROI (Return On Investment)` - показывает, на сколько процентов LTV превысил `CAC (Customer Acquisition Cost)` - стоимость привлечения пользователя за счет рекламных кампаний.

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %% [markdown]
# Применим функцию `filter_data()` для уменьшения шума и сглаживания графиков анализа. Это позволит визуально выделить общую тенденцию изменения рассматриваемых нами величин.

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# Теперь мы можем проанализировать окупаемость рекламных кампаний для нашего приложения.

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Таблица с профилями пользователей `profiles` была уже сформирована и мы можем ее использовать в вышеуказанных функциях для расчетов и анализа. Поскольку органические посетители не были привлечены в приложение при помощи рекламных кампаний, исключим пользователей с каналом привлечения `organic` из таблицы пользователей, то есть будем использовать далее таблицу `ad_acquisition_cost`, сформированную ранее, как таблицу профилей пользователей.

# %% [markdown]
# Мы смотрим на данные 1-го ноября 2019 года и указано считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей. Зададим момент и горизонт анализа для дальнейших расчетов.

# %%
observation_date = datetime(2020, 11, 1).date() # момент анализа
horizon_days = 14 # горизонт анализа

# %% [markdown]
# Проанализируем общую окупаемость рекламы. Рассчитаем и визуализируем `LTV` и `ROI`, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    ad_acquisition_cost, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Стоимость привлечения пользователей растет, а LTV в среднем остается на том же уровне (стабилен). В начале окупались позже - нет. Реклама не окупилась за весь срок, но из графика динамики видно, что в начале она окупалась (до середины июля). С этого момента ROI падает. ROI в конце второй недели около 80%. CAC не стабилен, стоимость привлечения пользователя постоянно растет. Возможно, проблема в этом.

# %% [markdown]
# Проанализировав полученные графики мы можем сказать, что:
# - LTV в динамике находится на уровне 0.9 и несмотря на резкие падения в среднем остается на этом уровне весь период.
# - CAC не стабилен, стоимость привлечения пользователей постоянно растет.
# - ROI в конце второй недели около 80% и не достигает уровня окупаемости. В динамике ROI непрерывно падает.

# %% [markdown]
# Таким образом, мы видим, что в начале периода рекламные кампании окупались, но уже с конца июня окупаемость резко пошла на спад. Можно сказать, что в целом реклама не окупилась за весь срок проведения. Возможно, дело в постоянном росте стоимости привлечения пользователей (бюджета рекламы) и низкой конверсии привлеченных пользователей.

# %% [markdown]
# Рассмотрим доступные нам характеристики пользователей, чтобы разобраться что повлияло на падение окупаемости рекламных кампаний.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=['device']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# При оценке графиков с разбивкой по устройствам мы можем заметить следующее:
# - Для пользователей, пользующихся PC, LTV ниже всего.
# - Динамика LTV для всех устройств в среднем устойчива.
# - Стоимость привлечения пользователей растет для всех устройств, но для IPhone и Mac рост стоимости более значительный.
# - ROI для IPhone и Mac самый низкий из всех платформ и окупаемость таких пользователей постоянно падает.
# - На уровне окупаемости находились пользователи PC, но с сентября и они перестали окупаться.

# %% [markdown]
# Можем сделать вывод, что окупаемость падает для всех устройств к концу рассматривамого периода. Привлечение пользователей IPhone и Mac имеет самую высокую стоимость, но их окупаемость непрерывно снижается. Здесь также видим, что реклама по устройствам в целом не окупилась.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Здесь отмечаем, что:
# - LTV у каналов TipTop, lambaMediaAds выше, чем у остальных. Также заметны сильные колебания в динамике LTV по каналам.
# - стоимость привлечения для канала TipTop значительно растет весь период, для остальных каналов остается в среднем на одном уровне.
# - каналы FaceBoom, TipTop и AdNonSense не окупаются на конец периода, а по графику динамике видим, что за весь срок они не окупились совсем и имели цену привлечения выше, чем у других каналов. Остальные каналы в среднем окупаются.

# %% [markdown]
# Таким образом, каналы с высокой стоимостью привлечения пользователей не окупаются за весь период. А другие каналы со стабильной более низкой ценой привлечения в целом окупились. То есть на привлечение пользователей в каналах FaceBoom, TipTop тратится значительный рекламный бюджет (помним из расчета расходов на маркетинг), но пользователи не окупаются.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# LTV выше у Unated States. Стомость привлечения пользователей из US растет весь период. Для остальных стран остается стабильной. По графику ROI полльзователи из US не окупаются, а другие - окупаются.

# %% [markdown]
# Проанализировав пользователей с разбивкой по странам видим следующее:
# - LTV выше у пользователей из United States.
# - cтомость привлечения пользователей из United States растет весь период, а для остальных стран остается стабильной.
# - уровень ROI для пользователей из United States ниже уровня окупаемости и постоянно падает весь период.
# - Пользователи из других стран в целом окупаются.

# %% [markdown]
# В итоге мы можем сделать вывод, что существует проблема окупаемости рекламных кампаний. Негативное влияние на общую картину окупаемости может оказывать:
# - рост стоимости рекламы для пользователей IPhone и Mac и их низкая окупаемость.
# - выделение наибольшего рекламного бюджета на каналы FaceBoom, TipTop и их самая низкая окупаемость.
# - высокая стоимость привлечения пользователей из United States и отсутствие окупаемости.

# %% [markdown]
# Посмотрим, чем могут быть вызваны проблемы окупаемости. Изучим также конверсию и удержание с разбивкой по устройствам, странам и рекламным каналам.

# %% [markdown]
# ### Конверсия и удержание по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Хуже всего конвертируются пользователи PC. А вот пользователи IPhone и Mac хорошо конвертируются. Рассмотрим удержание таких пользователей.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    ad_acquisition_cost, visits, observation_date, horizon_days, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Здесь видим, что удержание падает для всех пользователей устройств. Несмотря на хорошую конверсию и высокий бюджет рекламы пользователей IPhone и Mac, такие пользователи не задерживаются в приложении.

# %% [markdown]
# ### Конверсия и удержание по рекламным каналам

# %%
# смотрим конверсию с разбивкой по рекламным каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи, привлеченные из FaceBoom, AdNonSense и lambdaMediaAds имеют выше конверсию, чем привлеченные из других источников. Тем не менее она низкая. Заметим, что канал TipTop, на который выделяются самые значительные средства бюджета, привлекает платящих пользователей меньше, чем менее дорогие каналы (FaceBoom, AdNonSense и lambdaMediaAds). Это может быть основной проблемой.

# %%
# смотрим удержание с разбивкой по рекламным каналам

retention_raw, retention_grouped, retention_history = get_retention(
    ad_acquisition_cost, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей привлеченных из FaceBoom и AdNonSense падает почти до ноля. Вспомним, что рекламный бюджет FaceBoom второй по объему выделяемых средств.

# %% [markdown]
# ### Конверсия и удержание по странам

# %%
# смотрим конверсию с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_acquisition_cost, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи из United States конвертируются лучше, чем пользователи из других стран.

# %%
# смотрим удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    ad_acquisition_cost, visits, observation_date, horizon_days, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Но удержать привлеченных пользователей из United States сложно, их удержание ниже всех в когорте. А стоимость привлечения самая высокая. Пользователи из других стран имеют более высокий уровень удержания и ниже стоимость привлечения.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Мы провели аналитическое исследование приложения Procrastinate Pro+ и попытались разобраться в причинах неэффективности рекламных кампаний. Мы выяснили, что в целом реклама не окупилась за весь срок проведения. Также мы отметили следующие особенности:
# - каналы FaceBoom, TipTop и AdNonSense, на которые выделялялось больше всего рекламных средств, не окупились.
# - пользователи IPhone и Mac хорошо конвертируются, но их удержание стабильно падает.
# - пользователи, привлеченные из FaceBoom, AdNonSense и lambdaMediaAds имеют выше конверсию, чем привлеченные из других источников. Тем не менее она низкая.
# - канал TipTop, на который выделяются самые значительные средства бюджета, привлекает платящих пользователей меньше, чем менее дорогие каналы.
# - удержание платящих пользователей привлеченных из FaceBoom и AdNonSense падает почти до ноля. А конверсия у них хорошая, их нужно удерживать.
# - пользователи из United States имели высокий LTV, но окупались хуже всего, стоимость привлечения самая высокая. Другие страны со стабильным невысоким рекламным бюджетом в целом окупались.
# - рользователи из United States конвертируются лучше, чем пользователи из других стран. Но удержать привлеченных пользователей из United States сложно, их удержание ниже всех в когорте. На привлечения таких пользователей выделяется средств больше, чем на другие страны.

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# В качестве рекомендаций можно предложить отделу маркетинга обратить внимание на то, что пользователи из дорогостоящих каналов (TipTop, FaceBoom, AdNonSense) и  страны United States не окупаются. Пользователи IPhone и Mac не удерживаются приложением. Их удержание очень низкое, а конверсия высокая. Скорее всего, у таких пользователей выше требования к приложению и его функционалу. Необходимо оценить приложение с функциональной и пользовательской стороны и понять, почему пользователи с высокой конверсией уходят. Таких пользователей нужно удерживать.
# Нужно учесть, что канал TipTop не эффективен, он привлекает платящих пользователей меньше, чем более бюджетные каналы, а рекламных средств на него выделяется наибольшее количество. Возможно, нужно обратить внимание на более эффективное расходование средств на рекламу в остальных каналах и странах. Скорее всего, стоимость показов рекламы в популярных каналах за рассматриваемый период изменилась в сторону повышения и средства продолжали выделяться, но пользователи уже не окупаются при такой стоимости рекламы.
